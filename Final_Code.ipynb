# %% [markdown]
# <h1 align="center" style="font-family: 'Braniella', cursive; font-style: italic; font-size: 96px;">
#   Continuous Diffusion Language Model
# </h1>

# %% [markdown]
# ## Step-by-Step Guide: Training a Diffusion-Based Model on HellaSwag
#
# ---
#
# ### 1. **Imports and Setup**
#
# Start by importing all necessary Python packages:
#
# * `torch`, `nn`, `optim`: for deep learning.
# * `datasets`: to load the HellaSwag dataset.
# * `Counter`: to build a vocabulary.
# * `pad_sequence`, `DataLoader`, `Dataset`: for batching and token handling.
# * `math`, `os`: for numerical ops and file handling.
#
# ---
#
# ### 2. **Positional Embedding with Sinusoidal Encoding**
#
# We define a `SinusoidalPosEmb` class that takes in a timestep and produces a fixed positional embedding vector (like in transformers). This helps the model know "where in the diffusion process" it is.
#
# ---
#
# ### 3. **Diffusion Schedule**
#
# A `DiffusionSchedule` class is defined to:
#
# * Generate a sequence of `beta` values linearly spaced over time.
# * Derive `alpha` and `alpha_bar` values for the forward diffusion.
# * Implement `q_sample()`, which adds Gaussian noise to input embeddings according to the timestep — simulating the forward diffusion process.
#
# ---
#
# ### 4. **Dataset Preparation (HellaSwag)**
#
# A custom dataset class `HellaSwagDataset` is defined to:
#
# * Tokenize both the context and each of the four multiple-choice endings.
# * Convert words into token IDs using a vocabulary.
# * Return all four options (tokenized) and the correct label for each example.
#
# ---
#
# ### 5. **Collate Function for Padding**
#
# The `collate_fn()` function ensures:
#
# * Each batch is grouped by the answer position (i.e., all A choices together, all B choices together, etc.).
# * Sequences are padded so they can be stacked into uniform tensors.
#
# ---
#
# ### 6. **The Model: ContinuousDiffusionModel**
#
# This model:
#
# * Embeds tokens using `nn.Embedding`.
# * Projects sinusoidal timestep embeddings and adds them to token embeddings.
# * Feeds the result into an `LSTM`.
# * Outputs predicted denoised embeddings using a final linear layer.
#
# ---
#
# ### 7. **Training Logic**
#
# Inside the `train_model()` function:
#
# #### a. **Load HellaSwag Dataset**
#
# * Load 50,000 examples from the training set.
# * Load 100 examples from the validation set.
#
# #### b. **Build Vocabulary**
#
# * Go through all text in the dataset (context and endings).
# * Count word frequency.
# * Assign each word a unique token ID.
#
# #### c. **Create DataLoaders**
#
# * Use the `HellaSwagDataset` and `collate_fn()` to batch and pad sequences.
# * Shuffle training data.
#
# #### d. **Initialize Components**
#
# * Instantiate the model, optimizer (`Adam`), loss function (`MSE`), and diffusion schedule.
#
# ---
#
# ### 8. **Training Loop (50 Epochs)**
#
# For each epoch:
#
# #### a. **Training Phase**
#
# * For each batch:
#
#   * Sample random diffusion timesteps.
#   * For each answer option:
#
#     * Embed the tokens.
#     * Add noise (simulate forward process).
#     * Predict the noise using the model.
#     * Compute loss between predicted and real noise (MSE).
#     * Collect scores for all options.
#   * Compute accuracy based on which option the model thinks is easiest to denoise.
#
# #### b. **Validation Phase**
#
# * Repeat the above steps, but without gradient updates.
#
# #### c. **Print Metrics**
#
# * Log training and validation loss and accuracy for each epoch.
#
# ---
#
# ### 9. **Saving the Model**
#
# At the end of training:
#
# * Save the model's weights as `final_model.pth` under `./saved_models/`.
#
# ---
#
# ### 10. **Run Training**
#
# When the script is run (`__main__`), the `train_model()` function is called, kicking off the full training process.
#
# ---
#
# ## Summary of Key Features
#
# * This project applies **diffusion principles** to language modeling.
# * It **compares multiple-choice answers** by seeing which option's noise it can predict most confidently.
# * It uses **raw token embeddings** and applies **Gaussian noise + LSTM** to denoise them.
# * Accuracy is computed based on how well the model chooses the correct ending among four.
#
# ---

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence
from datasets import load_dataset
from collections import Counter
import os
import math

# Positional Embedding
class SinusoidalPosEmb(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim

    def forward(self, timestep):
        device = timestep.device
        half_dim = self.dim // 2
        emb_scale = math.log(10000) / (half_dim - 1)
        emb = torch.exp(torch.arange(half_dim, device=device) * -emb_scale)
        emb = timestep[:, None].float() * emb[None, :]
        return torch.cat([torch.sin(emb), torch.cos(emb)], dim=-1)

# Diffusion Schedule
class DiffusionSchedule:
    def __init__(self, timesteps=1000, beta_start=1e-4, beta_end=0.02):
        self.timesteps = timesteps
        self.beta = torch.linspace(beta_start, beta_end, timesteps)
        self.alpha = 1. - self.beta
        self.alpha_bar = torch.cumprod(self.alpha, dim=0)

    def q_sample(self, x_start, t, noise=None):
        if noise is None:
            noise = torch.randn_like(x_start)
        a_bar = self.alpha_bar[t].to(x_start.device).unsqueeze(-1).unsqueeze(-1)
        return torch.sqrt(a_bar) * x_start + torch.sqrt(1 - a_bar) * noise

# Dataset
class HellaSwagDataset(Dataset):
    def __init__(self, hf_dataset_split, vocab):
        self.data = hf_dataset_split
        self.vocab = vocab

    def tokenize(self, text):
        return [self.vocab.get(word, self.vocab['[UNK]']) for word in text.lower().split()]

    def __getitem__(self, idx):
        item = self.data[idx]
        context = item['ctx']
        endings = item['endings']
        label = int(item['label'])
        tokenized_choices = [torch.tensor(self.tokenize(context + " " + end), dtype=torch.long) for end in endings]
        return tokenized_choices, label

    def __len__(self):
        return len(self.data)

# Collate Function
def collate_fn(batch):
    all_choices, labels = [], []
    for choices, label in batch:
        all_choices.append(choices)
        labels.append(label)

    choices_per_pos = list(zip(*all_choices))
    padded_choices = [pad_sequence(choice_tensors, batch_first=True, padding_value=0)
                      for choice_tensors in choices_per_pos]

    return padded_choices, torch.tensor(labels, dtype=torch.long)

# Model
class ContinuousDiffusionModel(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, timestep_emb_dim=128):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.timestep_emb = SinusoidalPosEmb(timestep_emb_dim)
        self.timestep_proj = nn.Linear(timestep_emb_dim, embed_dim)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, batch_first=True)
        self.fc_out = nn.Linear(hidden_dim, embed_dim)

    def forward(self, x_tokens, t):
        emb = self.embedding(x_tokens)
        t_emb = self.timestep_emb(t)
        t_proj = self.timestep_proj(t_emb).unsqueeze(1)
        emb = emb + t_proj
        lstm_out, _ = self.lstm(emb)
        return self.fc_out(lstm_out)

# Training
def train_model():
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

    dataset_size = 50000
    hf_dataset_train = load_dataset("hellaswag", split=f"train[:{dataset_size}]", cache_dir="./cache", trust_remote_code=True)
    hf_dataset_val = load_dataset("hellaswag", split="validation[:100]", cache_dir="./cache", trust_remote_code=True)

    counter = Counter()
    for item in hf_dataset_train:
        counter.update(item['ctx'].lower().split())
        for end in item['endings']:
            counter.update(end.lower().split())

    vocab = {word: idx + 2 for idx, (word, _) in enumerate(counter.most_common())}
    vocab['[PAD]'] = 0
    vocab['[UNK]'] = 1

    train_dataset = HellaSwagDataset(hf_dataset_train, vocab)
    val_dataset = HellaSwagDataset(hf_dataset_val, vocab)

    train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, collate_fn=collate_fn)
    val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False, collate_fn=collate_fn)

    model = ContinuousDiffusionModel(len(vocab), 128, 256).to(device)
    diffusion = DiffusionSchedule()
    optimizer = optim.Adam(model.parameters(), lr=1e-3)
    criterion = nn.MSELoss()

    for epoch in range(50):
        model.train()
        total_loss, correct, samples = 0.0, 0, 0

        for padded_choices, labels in train_loader:
            batch_size = labels.size(0)
            labels = labels.to(device)
            optimizer.zero_grad()
            t = torch.randint(0, diffusion.timesteps, (batch_size,), device=device)

            losses, scores = [], []
            for choice in padded_choices:
                choice = choice.to(device)
                emb = model.embedding(choice)
                noise = torch.randn_like(emb)
                noisy_emb = diffusion.q_sample(emb, t, noise)
                noise_pred = model(choice, t)
                loss = criterion(noise_pred, noise)
                losses.append(loss)
                scores.append(-((noise_pred - noise) ** 2).mean(dim=[1, 2]))

            total = torch.stack(losses).sum()
            total.backward()
            optimizer.step()

            total_loss += total.item()
            pred = torch.stack(scores, dim=1).argmax(dim=1)
            correct += (pred == labels).sum().item()
            samples += batch_size

        print(f"Epoch {epoch+1} (Train): Train Loss = {total_loss/samples:.4f}, Accuracy = {correct/samples:.4f}")

        model.eval()
        val_loss, val_correct, val_samples = 0.0, 0, 0
        with torch.no_grad():
            for padded_choices, labels in val_loader:
                batch_size = labels.size(0)
                labels = labels.to(device)
                t = torch.randint(0, diffusion.timesteps, (batch_size,), device=device)

                losses, scores = [], []
                for choice in padded_choices:
                    choice = choice.to(device)
                    emb = model.embedding(choice)
                    noise = torch.randn_like(emb)
                    noisy_emb = diffusion.q_sample(emb, t, noise)
                    noise_pred = model(choice, t)
                    loss = criterion(noise_pred, noise)
                    losses.append(loss)
                    scores.append(-((noise_pred - noise) ** 2).mean(dim=[1, 2]))

                if losses:
                    val_loss += torch.stack(losses).sum().item()
                    pred = torch.stack(scores, dim=1).argmax(dim=1)
                    val_correct += (pred == labels).sum().item()
                    val_samples += batch_size

        print(f"Epoch {epoch+1} (Test): Val Loss = {val_loss/val_samples:.4f}, Accuracy = {val_correct/val_samples:.4f}")

    # Save the final trained model
    save_path = "./saved_models/final_model.pth"
    os.makedirs(os.path.dirname(save_path), exist_ok=True)
    torch.save(model.state_dict(), save_path)
    print(f"\n✅ Model saved to {save_path}")

# Entry point
if __name__ == "__main__":
    train_model()
# Out:
# Epoch 1 (Train): Train Loss = 0.2501, Accuracy = 0.2477
# Epoch 1 (Test): Val Loss = 0.2802, Accuracy = 0.2400
# Epoch 2 (Train): Train Loss = 0.2501, Accuracy = 0.2504
# Epoch 2 (Test): Val Loss = 0.2797, Accuracy = 0.3200
# Epoch 3 (Train): Train Loss = 0.2501, Accuracy = 0.2472
# Epoch 3 (Test): Val Loss = 0.2796, Accuracy = 0.2200
# Epoch 4 (Train): Train Loss = 0.2501, Accuracy = 0.2522
# Epoch 4 (Test): Val Loss = 0.2797, Accuracy = 0.2800
# Epoch 5 (Train): Train Loss = 0.2501, Accuracy = 0.2476
# Epoch 5 (Test): Val Loss = 0.2803, Accuracy = 0.2400
# Epoch 6 (Train): Train Loss = 0.2501, Accuracy = 0.2542
# Epoch 6 (Test): Val Loss = 0.2799, Accuracy = 0.3200
# Epoch 7 (Train): Train Loss = 0.2501, Accuracy = 0.2505
# Epoch 7 (Test): Val Loss = 0.2802, Accuracy = 0.2700
# Epoch 8 (Train): Train Loss = 0.2501, Accuracy = 0.2487
# Epoch 8 (Test): Val Loss = 0.2805, Accuracy = 0.3000
# Epoch 9 (Train): Train Loss = 0.2501, Accuracy = 0.2481
# Epoch 9 (Test): Val Loss = 0.2800, Accuracy = 0.2100
# Epoch 10 (Train): Train Loss = 0.2501, Accuracy = 0.2478
# Epoch 10 (Test): Val Loss = 0.2802, Accuracy = 0.2300
# Epoch 11 (Train): Train Loss = 0.2501, Accuracy = 0.2526
# Epoch 11 (Test): Val Loss = 0.2798, Accuracy = 0.3200
# Epoch 12 (Train): Train Loss = 0.2501, Accuracy = 0.2526
# Epoch 12 (Test): Val Loss = 0.2802, Accuracy = 0.2500
# Epoch 13 (Train): Train Loss = 0.2501, Accuracy = 0.2495
# Epoch 13 (Test): Val Loss = 0.2803, Accuracy = 0.2400
# Epoch 14 (Train): Train Loss = 0.2501, Accuracy = 0.2505
# Epoch 14 (Test): Val Loss = 0.2805, Accuracy = 0.2800
# Epoch 15 (Train): Train Loss = 0.2501, Accuracy = 0.2489
# Epoch 15 (Test): Val Loss = 0.2804, Accuracy = 0.2400
# Epoch 16 (Train): Train Loss = 0.2501, Accuracy = 0.2480
# Epoch 16 (Test): Val Loss = 0.2801, Accuracy = 0.2600
# Epoch 17 (Train): Train Loss = 0.2501, Accuracy = 0.2497
# Epoch 17 (Test): Val Loss = 0.2803, Accuracy = 0.2500
# Epoch 18 (Train): Train Loss = 0.2501, Accuracy = 0.2512
# Epoch 18 (Test): Val Loss = 0.2800, Accuracy = 0.2700
# Epoch 19 (Train): Train Loss = 0.2501, Accuracy = 0.2499
# Epoch 19 (Test): Val Loss = 0.2801, Accuracy = 0.2200
# Epoch 20 (Train): Train Loss = 0.2501, Accuracy = 0.2476
# Epoch 20 (Test): Val Loss = 0.2803, Accuracy = 0.2600
# Epoch 21 (Train): Train Loss = 0.2501, Accuracy = 0.2497
# Epoch 21 (Test): Val Loss = 0.2801, Accuracy = 0.2300
# Epoch 22 (Train): Train Loss = 0.2501, Accuracy = 0.2532
# Epoch 22 (Test): Val Loss = 0.2802, Accuracy = 0.2600
# Epoch 23 (Train): Train Loss = 0.2501, Accuracy = 0.2484
# Epoch 23 (Test): Val Loss = 0.2803, Accuracy = 0.2600
# Epoch 24 (Train): Train Loss = 0.2501, Accuracy = 0.2520
# Epoch 24 (Test): Val Loss = 0.2799, Accuracy = 0.2100
# Epoch 25 (Train): Train Loss = 0.2501, Accuracy = 0.2492
# Epoch 25 (Test): Val Loss = 0.2801, Accuracy = 0.2800
# Epoch 26 (Train): Train Loss = 0.2501, Accuracy = 0.2495
# Epoch 26 (Test): Val Loss = 0.2800, Accuracy = 0.3300
# Epoch 27 (Train): Train Loss = 0.2501, Accuracy = 0.2500
# Epoch 27 (Test): Val Loss = 0.2801, Accuracy = 0.2100
# Epoch 28 (Train): Train Loss = 0.2501, Accuracy = 0.2499
# Epoch 28 (Test): Val Loss = 0.2797, Accuracy = 0.2700
# Epoch 29 (Train): Train Loss = 0.2501, Accuracy = 0.2477
# Epoch 29 (Test): Val Loss = 0.2805, Accuracy = 0.2200
# Epoch 30 (Train): Train Loss = 0.2501, Accuracy = 0.2473
# Epoch 30 (Test): Val Loss = 0.2799, Accuracy = 0.2300
# Epoch 31 (Train): Train Loss = 0.2501, Accuracy = 0.2509
# Epoch 31 (Test): Val Loss = 0.2801, Accuracy = 0.2300
# Epoch 32 (Train): Train Loss = 0.2501, Accuracy = 0.2534
# Epoch 32 (Test): Val Loss = 0.2795, Accuracy = 0.2900
# Epoch 33 (Train): Train Loss = 0.2501, Accuracy = 0.2470
# Epoch 33 (Test): Val Loss = 0.2802, Accuracy = 0.3700
# Epoch 34 (Train): Train Loss = 0.2501, Accuracy = 0.2508
# Epoch 34 (Test): Val Loss = 0.2796, Accuracy = 0.2400
# Epoch 35 (Train): Train Loss = 0.2501, Accuracy = 0.2527
# Epoch 35 (Test): Val Loss = 0.2798, Accuracy = 0.2800
# Epoch 36 (Train): Train Loss = 0.2501, Accuracy = 0.2515
# Epoch 36 (Test): Val Loss = 0.2797, Accuracy = 0.2600
# Epoch 37 (Train): Train Loss = 0.2501, Accuracy = 0.2496
# Epoch 37 (Test): Val Loss = 0.2798, Accuracy = 0.2200
# Epoch 38 (Train): Train Loss = 0.2501, Accuracy = 0.2530
# Epoch 38 (Test): Val Loss = 0.2802, Accuracy = 0.2300
# Epoch 39 (Train): Train Loss = 0.2501, Accuracy = 0.2491
# Epoch 39 (Test): Val Loss = 0.2798, Accuracy = 0.2600
# Epoch 40 (Train): Train Loss = 0.2501, Accuracy = 0.2530
# Epoch 40 (Test): Val Loss = 0.2801, Accuracy = 0.2300
# Epoch 41 (Train): Train Loss = 0.2501, Accuracy = 0.2501
# Epoch 41 (Test): Val Loss = 0.2800, Accuracy = 0.2700
# Epoch 42 (Train): Train Loss = 0.2501, Accuracy = 0.2514
# Epoch 42 (Test): Val Loss = 0.2800, Accuracy = 0.2100
# Epoch 43 (Train): Train Loss = 0.2501, Accuracy = 0.2510
# Epoch 43 (Test): Val Loss = 0.2800, Accuracy = 0.2100
# Epoch 44 (Train): Train Loss = 0.2501, Accuracy = 0.2473
# Epoch 44 (Test): Val Loss = 0.2800, Accuracy = 0.3200
# Epoch 45 (Train): Train Loss = 0.2501, Accuracy = 0.2467
# Epoch 45 (Test): Val Loss = 0.2797, Accuracy = 0.2100
# Epoch 46 (Train): Train Loss = 0.2501, Accuracy = 0.2505
# Epoch 46 (Test): Val Loss = 0.2798, Accuracy = 0.2500
# Epoch 47 (Train): Train Loss = 0.2501, Accuracy = 0.2492
# Epoch 47 (Test): Val Loss = 0.2800, Accuracy = 0.1900
# Epoch 48 (Train): Train Loss = 0.2501, Accuracy = 0.2497
# Epoch 48 (Test): Val Loss = 0.2804, Accuracy = 0.2600
# Epoch 49 (Train): Train Loss = 0.2501, Accuracy = 0.2511
# Epoch 49 (Test): Val Loss = 0.2801, Accuracy = 0.3500
# Epoch 50 (Train): Train Loss = 0.2501, Accuracy = 0.2497
# Epoch 50 (Test): Val Loss = 0.2802, Accuracy = 0.2000
#
# ✅ Model saved to ./saved_models/final_model.pth

# %% [markdown]
# ---
#
# ### Step-by-Step Guide: Saving Vocabulary from the HellaSwag Dataset
#
# ---
#
# **1. Load Training Data**
# You start by loading a portion of the HellaSwag training dataset (e.g., 50,000 examples). This ensures you're using the same data that the model was trained on, which is important for consistency.
#
# ---
#
# **2. Count Word Frequencies**
# Next, for each example:
#
# * You extract the main context text and the list of possible endings.
# * You lowercase all words and split the text into individual tokens.
# * You use a counter to tally how often each word appears across the dataset.
#
# ---
#
# **3. Create the Vocabulary Dictionary**
# Once all words are counted:
#
# * You assign an index to each word, starting from 2 (to leave room for special tokens).
# * You explicitly add two special tokens:
#
#   * `[PAD]` with index `0` for padding.
#   * `[UNK]` with index `1` for unknown words not in the vocab.
#
# ---
#
# **4. Save the Vocabulary File**
# You then:
#
# * Create a directory if it doesn't exist (`./saved_models`).
# * Save the vocabulary dictionary as a file (`vocab.pkl`) using Python's `pickle` module.
#
# ---
#
# **5. Confirm Successful Save**
# Finally, you print a message showing how many entries are in your vocab and confirming that it was saved to the correct file path.
#
# ---
#
# ### Purpose
#
# This script prepares and preserves the vocabulary used during training so you can **re-use the exact same word-to-index mapping** later when evaluating the model or generating text.
#
# ---

# %%
import os
import pickle
from collections import Counter
from datasets import load_dataset

# Load the same data split you used for training
dataset_size = 50000
hf_dataset_train = load_dataset("hellaswag", split=f"train[:{dataset_size}]", cache_dir="./cache", trust_remote_code=True)

# Build vocab from training text
counter = Counter()
for item in hf_dataset_train:
    counter.update(item['ctx'].lower().split())
    for end in item['endings']:
        counter.update(end.lower().split())

# Create vocab dictionary
vocab = {word: idx + 2 for idx, (word, _) in enumerate(counter.most_common())}
vocab['[PAD]'] = 0
vocab['[UNK]'] = 1

# Save to file
os.makedirs("./saved_models", exist_ok=True)
with open("./saved_models/vocab.pkl", "wb") as f:
    pickle.dump(vocab, f)

print(f"✅ Vocab saved with {len(vocab)} entries to ./saved_models/vocab.pkl")
# Out:
# ✅ Vocab saved with 106630 entries to ./saved_models/vocab.pkl

# %% [markdown]
# ---
#
# ### Step-by-Step Guide: Loading a Saved Vocabulary
#
# ---
#
# **1. Open the Saved File**
# The script begins by locating and opening the file named `vocab.pkl` that was previously saved in the `./saved_models/` directory.
#
# ---
#
# **2. Load the Vocabulary into Memory**
# Using Python’s `pickle` module (which handles object serialization), the file is read and the saved vocabulary dictionary is loaded back into the program.
#
# ---
#
# **3. Result**
# After running this script, you'll have a `vocab` dictionary in memory that maps words to their corresponding integer IDs — exactly as they were during training.
#
# ---
#
# ### Purpose
#
# This allows you to **reuse the same vocabulary mapping** during model evaluation, inference, or text preprocessing — ensuring consistency with what the model was trained on.
#
# ---

# %%
import pickle

with open("./saved_models/vocab.pkl", "rb") as f:
    vocab = pickle.load(f)

# %% [markdown]
# ---
#
# ### Step-by-Step: Loading a Trained Model with Vocabulary
#
# ---
#
# #### 1. **Define the Sinusoidal Positional Embedding**
#
# * A custom neural network layer is created to generate embeddings based on a time step.
# * This is common in diffusion models and transformers, allowing the model to understand "when" a token appears.
#
# ---
#
# #### 2. **Build the Model Architecture**
#
# * A class called `ContinuousDiffusionModel` is defined:
#
#   * It uses a word embedding layer to turn token IDs into vectors.
#   * It adds a learned projection of the time step embedding to each word.
#   * Then it passes everything through an LSTM (a type of RNN).
#   * Finally, it uses a linear layer to map the output to the same dimensional space as the embeddings.
#
# ---
#
# #### 3. **Rebuild the Vocabulary**
#
# * The HellaSwag dataset (subset of 50,000 examples) is loaded.
# * A `Counter` goes through all words in the context (`ctx`) and endings to count word frequencies.
# * A vocabulary dictionary is created:
#
#   * Most common words get unique IDs starting from 2.
#   * Special tokens `[PAD]` and `[UNK]` are added with IDs 0 and 1.
#
# ---
#
# #### 4. **Initialize the Model**
#
# * A new instance of the model is created using the size of the reconstructed vocabulary.
# * The model is moved to GPU if available, otherwise it uses CPU.
#
# ---
#
# #### 5. **Load the Trained Weights**
#
# * The script attempts to load pre-trained weights from `./saved_models/final_model.pth`.
# * If successful, the model is put into evaluation mode (inference-ready).
# * If it fails (e.g., due to vocabulary mismatch), an error message is printed.
#
# ---
#
# ### Result:
#
# By the end of this script:
#
# * You have a fully defined model architecture.
# * The vocabulary used during training has been rebuilt.
# * The trained model weights are loaded, and the model is ready for use.
#
# ---

# %%
import torch
import torch.nn as nn
import math
from collections import Counter
from datasets import load_dataset

# Sinusoidal Positional Embedding
class SinusoidalPosEmb(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim

    def forward(self, timestep):
        device = timestep.device
        half_dim = self.dim // 2
        emb_scale = math.log(10000) / (half_dim - 1)
        emb = torch.exp(torch.arange(half_dim, device=device) * -emb_scale)
        emb = timestep[:, None].float() * emb[None, :]
        return torch.cat([torch.sin(emb), torch.cos(emb)], dim=-1)

# Model Definition
class ContinuousDiffusionModel(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, timestep_emb_dim=128):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.timestep_emb = SinusoidalPosEmb(timestep_emb_dim)
        self.timestep_proj = nn.Linear(timestep_emb_dim, embed_dim)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, batch_first=True)
        self.fc_out = nn.Linear(hidden_dim, embed_dim)

    def forward(self, x_tokens, t):
        emb = self.embedding(x_tokens)
        t_emb = self.timestep_emb(t)
        t_proj = self.timestep_proj(t_emb).unsqueeze(1)
        emb = emb + t_proj
        lstm_out, _ = self.lstm(emb)
        return self.fc_out(lstm_out)

# Vocab Reconstruction
hf_dataset_train = load_dataset("hellaswag", split="train[:50000]", cache_dir="./cache", trust_remote_code=True)

counter = Counter()
for item in hf_dataset_train:
    counter.update(item['ctx'].lower().split())
    for end in item['endings']:
        counter.update(end.lower().split())

vocab = {word: idx + 2 for idx, (word, _) in enumerate(counter.most_common())}
vocab['[PAD]'] = 0
vocab['[UNK]'] = 1

# Load the Model Weights
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ContinuousDiffusionModel(len(vocab), 128, 256).to(device)

try:
    model.load_state_dict(torch.load("./saved_models/final_model.pth", map_location=device))
    model.eval()
    print("✅ Model loaded and ready to use.")
except Exception as e:
    print("❌ Failed to load model:", e)
# Out:
# ✅ Model loaded and ready to use.

# %% [markdown]
# ---
#
# ### Step-by-Step: Evaluating a Trained Diffusion-Based Model on HellaSwag
#
# ---
#
# #### 1. **Import Required Libraries**
#
# The script imports PyTorch, dataset handling (`datasets`), `pickle` (for loading the saved vocabulary), and other essentials for model evaluation.
#
# ---
#
# #### 2. **Redefine the Necessary Classes**
#
# These classes are reused from training, so they are redefined here to match the structure used when training the model:
#
# * **`SinusoidalPosEmb`**: Creates a positional embedding based on the timestep.
# * **`ContinuousDiffusionModel`**: Neural model with embeddings, an LSTM layer, and a linear output layer.
# * **`DiffusionSchedule`**: Defines how noise is added over time using a beta schedule.
# * **`HellaSwagDataset`**: Prepares the dataset for use with your model (including tokenization).
# * **`collate_fn`**: Handles padding and batching during loading.
#
# ---
#
# #### 3. **Load the Dataset**
#
# * Loads 100 validation samples from the HellaSwag dataset using Hugging Face’s `load_dataset` function.
# * This dataset will be used to test the model’s multiple-choice prediction ability.
#
# ---
#
# #### 4. **Load the Vocabulary**
#
# * Reads the previously saved vocabulary (`vocab.pkl`) from disk.
# * This ensures token IDs match what the model was trained with.
#
# ---
#
# #### 5. **Rebuild the Model**
#
# * Reconstructs the trained model with the correct vocabulary size and architecture.
# * Loads pre-trained weights from `final_model.pth`.
#
# ---
#
# #### 6. **Prepare the Dataset and DataLoader**
#
# * The validation set is processed into a custom PyTorch `Dataset`.
# * A `DataLoader` is created to iterate over each example (1 at a time).
#
# ---
#
# #### 7. **Run the Evaluation Loop**
#
# * For each question in the validation set:
#
#   * All four answer choices are embedded.
#   * Noise is added using the diffusion schedule.
#   * The model predicts the noise for each choice.
#   * The mean squared error (MSE) between predicted and actual noise is calculated.
#   * The choice with the lowest MSE is selected as the model’s prediction.
# * The model's prediction is compared to the ground-truth label.
#
# ---
#
# #### 8. **Print the Results**
#
# * For each question:
#
#   * The context and all answer choices are printed.
#   * The model’s prediction is shown, along with the correct answer.
# * At the end:
#
#   * The script prints the total accuracy over the 100 validation examples.
#
# ---
#
# ### Result
#
# You get a detailed evaluation report showing:
#
# * Which questions the model got right or wrong.
# * How confident it was (based on the MSE scores).
# * The overall accuracy across all tested samples.
#
# ---

# %%
import torch
import torch.nn.functional as F
from datasets import load_dataset
from collections import Counter
import math
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence
import pickle

# Re-define or import your classes here:
# If you saved your training script as `your_diffusion_script.py`, you can do:
# from your_diffusion_script import ContinuousDiffusionModel, DiffusionSchedule, HellaSwagDataset, collate_fn


# Redefine SinusoidalPosEmb (needed by model)
class SinusoidalPosEmb(nn.Module):
    def __init__(self, dim):
        super().__init__()
        self.dim = dim

    def forward(self, timestep):
        device = timestep.device
        half_dim = self.dim // 2
        emb_scale = math.log(10000) / (half_dim - 1)
        emb = torch.exp(torch.arange(half_dim, device=device) * -emb_scale)
        emb = timestep[:, None].float() * emb[None, :]
        return torch.cat([torch.sin(emb), torch.cos(emb)], dim=-1)

# Redefine ContinuousDiffusionModel
class ContinuousDiffusionModel(nn.Module):
    def __init__(self, vocab_size, embed_dim, hidden_dim, timestep_emb_dim=128):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.timestep_emb = SinusoidalPosEmb(timestep_emb_dim)
        self.timestep_proj = nn.Linear(timestep_emb_dim, embed_dim)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, batch_first=True)
        self.fc_out = nn.Linear(hidden_dim, embed_dim)

    def forward(self, x_tokens, t):
        emb = self.embedding(x_tokens)
        t_emb = self.timestep_emb(t)
        t_proj = self.timestep_proj(t_emb).unsqueeze(1)
        emb = emb + t_proj
        lstm_out, _ = self.lstm(emb)
        return self.fc_out(lstm_out)

# Redefine DiffusionSchedule
class DiffusionSchedule:
    def __init__(self, timesteps=1000, beta_start=1e-4, beta_end=0.02):
        self.timesteps = timesteps
        self.beta = torch.linspace(beta_start, beta_end, timesteps)
        self.alpha = 1. - self.beta
        self.alpha_bar = torch.cumprod(self.alpha, dim=0)

    def q_sample(self, x_start, t, noise=None):
        if noise is None:
            noise = torch.randn_like(x_start)
        a_bar = self.alpha_bar[t].to(x_start.device).unsqueeze(-1).unsqueeze(-1)
        return torch.sqrt(a_bar) * x_start + torch.sqrt(1 - a_bar) * noise

# Redefine Dataset and collate_fn

class HellaSwagDataset(Dataset):
    def __init__(self, hf_dataset_split, vocab):
        self.data = hf_dataset_split
        self.vocab = vocab

    def tokenize(self, text):
        return [self.vocab.get(word, self.vocab['[UNK]']) for word in text.lower().split()]

    def __getitem__(self, idx):
        item = self.data[idx]
        context = item['ctx']
        endings = item['endings']
        label = int(item['label'])
        tokenized_choices = [torch.tensor(self.tokenize(context + " " + end), dtype=torch.long) for end in endings]
        return tokenized_choices, label

    def __len__(self):
        return len(self.data)

def collate_fn(batch):
    all_choices = []
    labels = []
    for choices, label in batch:
        all_choices.append(choices)
        labels.append(label)

    choices_per_pos = list(zip(*all_choices))
    padded_choices = [pad_sequence(choice_tensors, batch_first=True, padding_value=0)
                      for choice_tensors in choices_per_pos]

    return padded_choices, torch.tensor(labels, dtype=torch.long)

# Load dataset, vocab, model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

hf_val = load_dataset("hellaswag", split="validation[:100]", cache_dir="./cache", trust_remote_code=True)
with open('./saved_models/vocab.pkl', 'rb') as f:
    vocab = pickle.load(f)

model = ContinuousDiffusionModel(len(vocab), 128, 256).to(device)
model.load_state_dict(torch.load("./saved_models/final_model.pth", map_location=device))
model.eval()

diffusion = DiffusionSchedule(timesteps=1000)  # Use the same timesteps as in your training

val_dataset = HellaSwagDataset(hf_val, vocab)
val_loader = DataLoader(val_dataset, batch_size=1, shuffle=False, collate_fn=collate_fn)

# Evaluation loop
total, correct = 0, 0

for padded_choices, labels in val_loader:
    labels = labels.to(device)
    t = torch.randint(0, diffusion.timesteps, (1,), device=device)

    scores = []
    for choice_seq in padded_choices:
        choice_seq = choice_seq.to(device)
        emb = model.embedding(choice_seq)
        noise = torch.randn_like(emb)
        noisy_emb = diffusion.q_sample(emb, t, noise)
        noise_pred = model(choice_seq, t)
        mse = F.mse_loss(noise_pred, noise, reduction='none').mean(dim=[1, 2])
        scores.append(-mse)

    scores = torch.stack(scores, dim=1)  # [batch, num_choices]
    pred = scores.argmax(dim=1)
    total += 1
    correct += (pred == labels).item()

    ctx = hf_val[int(total) - 1]['ctx']
    endings = hf_val[int(total) - 1]['endings']
    print(f"\nQ{total}: {ctx}")
    for idx, end in enumerate(endings):
        mark = "✅" if idx == labels.item() else ""
        print(f"  [{idx}] {end} (score={scores[0, idx].item():.2f}) {mark}")
    print(f"→ Predicted: {pred.item()} | Ground Truth: {labels.item()} {'✅' if pred==labels else '❌'}")

accuracy = correct / total * 100
print(f"\nFinal Accuracy on {total} samples: {correct}/{total} = {accuracy:.2f}%")
# Out:
# Q1: A man is sitting on a roof. he
#   [0] is using wrap to wrap a pair of skis. (score=-1.01)
#   [1] is ripping level tiles off. (score=-1.05)
#   [2] is holding a rubik's cube. (score=-1.02)
#   [3] starts pulling up roofing on a roof. (score=-0.98) ✅
# → Predicted: 3 | Ground Truth: 3 ✅
#
# Q2: A lady walks to a barbell. She bends down and grabs the pole. the lady
#   [0] swings and lands in her arms. (score=-0.97)
#   [1] pulls the barbell forward. (score=-0.99)
#   [2] pulls a rope attached to the barbell. (score=-0.98)
#   [3] stands and lifts the weight over her head. (score=-1.00) ✅
# → Predicted: 0 | Ground Truth: 3 ❌
#
# Q3: Two women in a child are shown in a canoe while a man pulls the canoe while standing in the water, with other individuals visible in the background. the child and a different man
#   [0] are then shown paddling down a river in a boat while a woman talks. (score=-1.01)
#   [1] are driving the canoe, they go down the river flowing side to side. (score=-1.02)
#   [2] sit in a canoe while the man paddles. (score=-1.03) ✅
#   [3] walking go down the rapids, while the man in his helicopter almost falls and goes out of canoehood. (score=-1.00)
# → Predicted: 3 | Ground Truth: 2 ❌
#
# Q4: A boy is running down a track. the boy
#   [0] runs into a car. (score=-1.02)
#   [1] gets in a mat. (score=-0.98)
#   [2] lifts his body above the height of a pole. (score=-0.94) ✅
#   [3] stands on his hands and springs. (score=-1.00)
# → Predicted: 2 | Ground Truth: 2 ✅
#
# Q5: The boy lifts his body above the height of a pole. The boy lands on his back on to a red mat. the boy
#   [0] turns his body around on the mat. (score=-1.02)
#   [1] gets up from the mat. (score=-0.99) ✅
#   [2] continues to lift his body over the pole. (score=-1.02)
#   [3] wiggles out of the mat. (score=-1.02)
# → Predicted: 1 | Ground Truth: 1 ✅
#
# Q6: The boy lands on his back on to a red mat. The boy gets up from the mat. the boy
#   [0] starts doing spins. (score=-0.99)
#   [1] celebrates by clapping and flexing both arms. (score=-0.97) ✅
#   [2] is dancing on the mat. (score=-0.96)
#   [3] does jump jacks on his stick. (score=-1.00)
# → Predicted: 2 | Ground Truth: 1 ❌
#
# Q7: A man is standing in front of a camera. He starts playing a harmonica for the camera. he
#   [0] begins to play the harmonica with his body while looking at the camera. (score=-1.02)
#   [1] seems to be singing while playing the harmonica. (score=-1.00)
#   [2] rocks back and forth to the music as he goes. (score=-0.97) ✅
#   [3] painted a fence in front of the camera. (score=-1.01)
# → Predicted: 2 | Ground Truth: 2 ✅
#
# Q8: A cartoon animation video is shown with people wandering around and rockets being shot. two men
#   [0] fight robots of evil and ends with a to be continued. (score=-0.94) ✅
#   [1] are then shown in closeups shooting a shot put. (score=-1.05)
#   [2] push a child in a speedboat in the water. (score=-1.02)
#   [3] look in the cameraman's eye and smile. (score=-1.01)
# → Predicted: 0 | Ground Truth: 0 ✅
#
# Q9: A man is holding a pocket knife while sitting on some rocks in the wilderness. then he
#   [0] opens a can of oil put oil on the knife, and puts oil on a knife and press it through a can filled with oil then cuts several pieces from the sandwiches. (score=-1.02)
#   [1] takes a small stone from the flowing river and smashes it on another stone. (score=-1.02) ✅
#   [2] uses the knife to shave his leg. (score=-0.97)
#   [3] sand the rocks and tops them by using strong pressure. (score=-1.03)
# → Predicted: 2 | Ground Truth: 1 ❌
#
# Q10: Then he takes a small stone from the flowing river and smashes it on another stone. He starts to crush the small stone to smaller pieces. he
#   [0] cuts the center stone in half and blow it on to make it bigger. (score=-1.01)
#   [1] grind it hard to make the pieces smaller. (score=-1.00) ✅
#   [2] eventually brings it back into view and adds it to the smaller ones to make a small triangular shaped piece. (score=-1.02)
#   [3] starts to party with them and throw the pieces by hand while they celebrate. (score=-0.98)
# → Predicted: 3 | Ground Truth: 1 ❌
#
# Q11: Then he takes a piece of bark and rubs the powered stone pieces onto it. The stone particles stick to the wet piece of wood. he
#   [0] uses a small brush to polish one of the stone pieces. (score=-1.01)
#   [1] then uses a strip of sealing tape to seal the board and then smooths the bottom of the board. (score=-1.01)
#   [2] walks towards the camera. (score=-0.99)
#   [3] then takes the knife and sharpens it against the wood piece. (score=-0.98) ✅
# → Predicted: 3 | Ground Truth: 3 ✅
#
# Q12: The stone particles stick to the wet piece of wood. He then takes the knife and sharpens it against the wood piece. he
#   [0] then cuts off the excess hair of the wood. (score=-1.00)
#   [1] scrapes the wood with a broom in the cutting tool used in sharpening the instrument. (score=-1.02)
#   [2] writes on the board again. (score=-1.00)
#   [3] then notices a little black and green poisonous frog sitting next to him. (score=-1.03) ✅
# → Predicted: 0 | Ground Truth: 3 ❌
#
# Q13: He then takes the knife and sharpens it against the wood piece. He then notices a little black and green poisonous frog sitting next to him. the frog
#   [0] eventually gets to get up and marches out of the room waving its body about. (score=-0.97)
#   [1] then starts to get up from the chair and begins walking towards the camera. (score=-1.01)
#   [2] then escapes and jumps away. (score=-1.00) ✅
#   [3] is acting crazy and attacking him while he is cooking. (score=-1.01)
# → Predicted: 0 | Ground Truth: 2 ❌
#
# Q14: He then notices a little black and green poisonous frog sitting next to him. The frog then escapes and jumps away. he
#   [0] sits and hugs another man and also adjusts his camera. (score=-1.02)
#   [1] then sits there staring at his text machine as if he has actually been given a gift from god. (score=-0.99)
#   [2] explains how the frog secretes a poisonous fluid that can be extremely harmful. (score=-1.00) ✅
#   [3] takes the frog on his hand and tickles the back of it. (score=-0.96)
# → Predicted: 3 | Ground Truth: 2 ❌
#
# Q15: A person is playing bagpipes out in a park. A man and two boys watching from a far. the camera
#   [0] shoots areas all around the park while the bagpipes play. (score=-0.96) ✅
#   [1] is covered to the boy that is playing there. (score=-0.99)
#   [2] then goes black and we see a black opening scene. (score=-1.03)
#   [3] watching the boy and boy as they play a game of drums. (score=-1.01)
# → Predicted: 0 | Ground Truth: 0 ✅
#
# Q16: Two people are seen passing a ball back and fourth in a pool and leads into one speaking to the camera. the man
#   [0] dips the ball and walks back with the boy and pours detergent into a cup again. (score=-1.04)
#   [1] then throws the ball into the pool and begins running around with a sail in his hand while a group of men watch. (score=-0.99)
#   [2] then takes a drink having a conversation with another man and another man leads into him throwing balls in the water and laughing to the camera. (score=-1.01)
#   [3] demonstrates how to properly throw the ball with his hands while still speaking to the camera. (score=-1.01) ✅
# → Predicted: 1 | Ground Truth: 3 ❌
#
# Q17: A woman is sitting at a table in a fast food restaurant while eating. She continually speaks to nobody as she eats. she
#   [0] is then seen sitting alone as she eats a cold brown ice cream. (score=-1.00)
#   [1] pauses in the process of eating to enjoy her food. (score=-1.00)
#   [2] stands up and grabs her purse, continuing to talk and laugh as she leaves. (score=-1.01) ✅
#   [3] picks up another chocolate bar and chews it as she talks. (score=-1.01)
# → Predicted: 0 | Ground Truth: 2 ❌
#
# Q18: A group of cheerleaders run onto a stage before a cheering audience. they
#   [0] get into formation, then begin dancing and flipping as male cheerleaders join them. (score=-1.01) ✅
#   [1] perform a cheer routine before the girls, along with makeup artists, spread out and pose. (score=-1.00)
#   [2] take turns jumping on each other like they are performing karate. (score=-1.01)
#   [3] are then shown performing the type of cheerleading dance, using batons and pole vaults. (score=-0.98)
# → Predicted: 3 | Ground Truth: 0 ❌
#
# Q19: A group of cheerleaders run onto a stage before a cheering audience. They get into formation, then begin dancing and flipping as male cheerleaders join them. they all
#   [0] dance and flip on stage while hanging their hats on the sides. (score=-1.02)
#   [1] continue dancing and flipping, doing hand springs. (score=-1.00) ✅
#   [2] dance together with flip up their sleeves. (score=-1.00)
#   [3] perform their routines as the studio rashes to a halt with cheerleaders in the audience. (score=-1.01)
# → Predicted: 2 | Ground Truth: 1 ❌
#
# Q20: They get into formation, then begin dancing and flipping as male cheerleaders join them. They all continue dancing and flipping, doing hand springs. when they
#   [0] are done, they shake hands and walk away, but cheers are heard all around as they're finished. (score=-1.01)
#   [1] are finished, they jump up and down happily and walk off the stage, exhausted. (score=-0.98) ✅
#   [2] are done, a male cheerleader is crowned and an instant replay is shown. (score=-0.99)
#   [3] come down from their workout, they all stop to bow and applaud, then they continue dancing. (score=-1.00)
# → Predicted: 1 | Ground Truth: 1 ✅
#
# Q21: A woman is reading a newspaper nearby while he speaks to her and shows her something in his hand. The man sharpens his knives using an electric tool. he
#   [0] sharpens and cuts something on a knife board using an electric tool. (score=-1.01)
#   [1] then continues cutting his onion. (score=-0.97) ✅
#   [2] travels with his knife under the table and uses it also in his shoe. (score=-1.00)
#   [3] then shows her a spare knife that he has also used on a knife sharpener and drills into a side of the table. (score=-1.03)
# → Predicted: 1 | Ground Truth: 1 ✅
#
# Q22: A man is outside of a building. He is using commercial lawn mowing equipment. he
#   [0] walks back and forth as he mows the grass. (score=-1.00) ✅
#   [1] is animated as he does the task. (score=-0.99)
#   [2] relaxes, making sure his lawn is pristine. (score=-0.97)
#   [3] runs from one side of the building to the other. (score=-1.00)
# → Predicted: 2 | Ground Truth: 0 ❌
#
# Q23: Children bring desert out for their family member. the family
#   [0] floats in a river. (score=-0.99)
#   [1] member stands looking into a hut and then handing people photographs. (score=-1.01)
#   [2] member cuts a piece of sunscreen. (score=-1.01)
#   [3] enjoys eating the desert together. (score=-0.98) ✅
# → Predicted: 3 | Ground Truth: 3 ✅
#
# Q24: The family enjoys eating the desert together. The people in the restaurant laugh at the man and he wonders what they are doing. the man
#   [0] goes to the bathroom and isn't able to get very far. (score=-1.05)
#   [1] puts the glass aside and a fourth person walks in and walks away. (score=-1.02)
#   [2] plays the bagpipe and smiles and laughs as he enjoys the hospitality. (score=-1.02)
#   [3] gets up and walks away to the other room. (score=-1.03) ✅
# → Predicted: 2 | Ground Truth: 3 ❌
#
# Q25: A black female is shown in a room with a black scarf around her head. black spots on her faced
#   [0] are then zoomed in on and she begins to apply something on it. (score=-1.00) ✅
#   [1] are shown and she misses a little bit of her swing. (score=-0.97)
#   [2] are shown and one finger is seen poking through. (score=-0.99)
#   [3] are shown as she continues to dance around on the hardwood and every move makes a lash on her face. (score=-1.01)
# → Predicted: 1 | Ground Truth: 0 ❌
#
# Q26: A black female is shown in a room with a black scarf around her head. Black spots on her faced are then zoomed in on and she begins to apply something on it. next
#   [0] , she begins to brush her lips and make painted lips look just like a lipstick to the camera and ends with her closing gift and instruction showing her off at the end. (score=-0.99)
#   [1] she is shown in various different locations and gets extremely close to a wall. (score=-0.99)
#   [2] , she is shown making multiple moans and sprays some kind of liquid down her face before hanging up. (score=-1.01)
#   [3] , she takes some spray and it makes her skin extremely oily and she continues to talk until the video is over. (score=-1.00) ✅
# → Predicted: 1 | Ground Truth: 3 ❌
#
# Q27: A helicopter flies in some people who then start playing paintball. they
#   [0] run around obstacles and have a great time. (score=-0.96) ✅
#   [1] lose their shirt during the fight and run back the others. (score=-0.94)
#   [2] shoot at each other while the helicopter drone who am looking on. (score=-1.04)
#   [3] chase a bird in the sky while others walk around. (score=-1.01)
# → Predicted: 1 | Ground Truth: 0 ❌
#
# Q28: A young boy and girl are standing over a sink with their mother talking. the mother
#   [0] is now putting lipstick on the boy's mouth and he tries to stop her but only gets a little bit stuck. (score=-0.98)
#   [1] washes the boy while the child grabs shampoo. (score=-0.98)
#   [2] shows some shaving cream on the boy who is scrubbing her brushes. (score=-0.97)
#   [3] instructs them on how to brush their teeth while laughing. (score=-0.99) ✅
# → Predicted: 2 | Ground Truth: 3 ❌
#
# Q29: A young boy and girl are standing over a sink with their mother talking. The mother instructs them on how to brush their teeth while laughing. the boy
#   [0] puts a shirt on and rubs his mouth. (score=-0.98)
#   [1] helps his younger sister brush his teeth. (score=-0.98) ✅
#   [2] walks with an empty mouthwash cup on a sink floor. (score=-0.99)
#   [3] and girl then begin working out. (score=-0.99)
# → Predicted: 0 | Ground Truth: 1 ❌
#
# Q30: The mother instructs them on how to brush their teeth while laughing. The boy helps his younger sister brush his teeth. she
#   [0] shows how to hit the mom and then kiss his dad as well. (score=-1.01)
#   [1] brushes past the camera, looking better soon after. (score=-1.01)
#   [2] glows from the center of the camera as a reaction. (score=-0.97)
#   [3] gets them some water to gargle in their mouths. (score=-1.00) ✅
# → Predicted: 2 | Ground Truth: 3 ❌
#
# Q31: She gets them some water to gargle in their mouths. The boy and girl begin playing in the sink. the woman
#   [0] shakes her head in disbelief and waves at her. (score=-1.04)
#   [1] laughs at the children dribbling water. (score=-0.97) ✅
#   [2] comes back and talks to the boys. (score=-1.00)
#   [3] gets some food out of the fridge and they continue playing together. (score=-1.00)
# → Predicted: 1 | Ground Truth: 1 ✅
#
# Q32: A cat is sitting in a cat bed. It is licking its paw. it
#   [0] then wipes its paw on its ear. (score=-1.00) ✅
#   [1] crawls to the door. (score=-0.97)
#   [2] 's laying down about six inches away from the camera. (score=-1.02)
#   [3] crawls on one foot to get closer to the camera. (score=-0.96)
# → Predicted: 3 | Ground Truth: 0 ❌
#
# Q33: A man in brown jacket is pulling out an arrow from the target board, then he was talking to the camera, then he pull out his bow and started to use it with his bow to hit the target board, he fired his bows several times. the man
#   [0] played paper if and shoot the arrows to hit the target, then he hang from the board with his bow and arrow. (score=-1.00)
#   [1] went to the target board and talked to the camera. (score=-1.00) ✅
#   [2] eventually throw the arrow, but it flew into the gravel is near the targets. (score=-1.02)
#   [3] have his bow as he talk to the camera, he pulled it out to show how to put with its flex, tighten, and notch that was attached to his bow. (score=-0.98)
# → Predicted: 3 | Ground Truth: 1 ❌
#
# Q34: A man walks outside plugs his lawn mower in and gets ready to mow. he
#   [0] drives through the grass while drinking from a large cup of water and carrying his lawn mower. (score=-0.99)
#   [1] walks off the porch and goes back inside. (score=-0.99)
#   [2] starts mowing his lawn casually going over all the grass. (score=-0.98) ✅
#   [3] does this multiple times until a pale orange moon appears overhead. (score=-1.00)
# → Predicted: 2 | Ground Truth: 2 ✅
#
# Q35: A man walks outside plugs his lawn mower in and gets ready to mow. He starts mowing his lawn casually going over all the grass. his dog
#   [0] comes outside and starts to follow him a little while he's closer to the house. (score=-1.03) ✅
#   [1] comes outside and takes a closer look at the man mowing, after he picks up the mower. (score=-0.98)
#   [2] runs loose and feeds on his movements. (score=-0.99)
#   [3] is having a seizure and starts to hop all over the lawn as he walks around. (score=-0.97)
# → Predicted: 3 | Ground Truth: 0 ❌
#
# Q36: He starts mowing his lawn casually going over all the grass. His dog comes outside and starts to follow him a little while he's closer to the house. the yard
#   [0] is slowly starting to look really really nice, once he is completely finished the yard looks great, nice and smooth. (score=-1.01) ✅
#   [1] is very neat and clean and very active under the circumstances. (score=-1.00)
#   [2] gets mowed quicker by the dog. (score=-1.02)
#   [3] eventually looks happy on the outside and appears to be going pretty happily. (score=-0.98)
# → Predicted: 3 | Ground Truth: 0 ❌
#
# Q37: A sea is shown with a green forest on seashore. Blond man is standing in seashore and talking to the camera and surfing big waves on the sea. man
#   [0] is on ocean and swimming in white water snapping his head. (score=-0.97)
#   [1] is snowboarding up in the sea. (score=-1.02)
#   [2] is doing flips in the waters and on the rocks and he be water surfing. (score=-1.00)
#   [3] is walking on seashore through a lot of people and talking to the camera and holding an award and talking about surfing the seashore. (score=-0.99) ✅
# → Predicted: 0 | Ground Truth: 3 ❌
#
# Q38: We see a bottle of face wash. we
#   [0] see a newspaper story. (score=-1.00)
#   [1] see four cookies in a pan. (score=-1.02)
#   [2] see a person holding face wash then putting it on their face. (score=-1.02) ✅
#   [3] see a tool on a table. (score=-0.96)
# → Predicted: 3 | Ground Truth: 2 ❌
#
# Q39: We see a person holding face wash then putting it on their face. They rinse the face and add the face wash with a brush. we
#   [0] see a closing title screen. (score=-1.02)
#   [1] see a black screen with the credits. (score=-1.02)
#   [2] see an illustration on how to add the wash using a brush. (score=-1.01) ✅
#   [3] then see a replay then the person putting the face wash on. (score=-1.05)
# → Predicted: 2 | Ground Truth: 2 ✅
#
# Q40: A person is seen throwing plaster onto a wall while the camera follows the person close behind. the person
#   [0] continues throwing ingredients down and leads into a person kicking a dirty toilet. (score=-1.01)
#   [1] gradually throws more and more onto the wall and the camera pans over the finished product. (score=-0.95) ✅
#   [2] then uses paper to spread it all over the wall followed by others putting paper through with the plaster. (score=-0.99)
#   [3] is now seen putting wax all along the wall while still looking back to the camera. (score=-0.99)
# → Predicted: 1 | Ground Truth: 1 ✅
#
# Q41: More and more people begin talking and each of them has a bottle of sun screen and starts to squirt it on their arms in effort to protect their skin. a small blue bottle of the sun screen
#   [0] appears and then different people carry it to a table where they mix the liquid with a straw with a straw and take turns squirting the liquid into their skin. (score=-1.03)
#   [1] appears near each of their hair as they continue to talk but no bottle at all appear. (score=-0.99)
#   [2] is then shown and several more people begin talking about the product. (score=-1.01) ✅
#   [3] zooms in on sheers that they have on the floor. (score=-1.01)
# → Predicted: 1 | Ground Truth: 2 ❌
#
# Q42: A group of boys are standing in a room with many clear cups of beer on a table they are all standing around. the boys
#   [0] take a flute together and then begin to play the harmonica using it to play the tune. (score=-1.00)
#   [1] begin to wrap red bow around the plastic cups, put bows on the bottoms _start_various objects on the foam covers and belongings to the floor. (score=-0.96)
#   [2] talk, laugh and tease each other before beginning a game of beer pong across a long table using a triangle shaped array of clear cups. (score=-0.98) ✅
#   [3] all grab one and chug their contents of the cans. (score=-0.99)
# → Predicted: 1 | Ground Truth: 2 ❌
#
# Q43: The boys talk, laugh and tease each other before beginning a game of beer pong across a long table using a triangle shaped array of clear cups. one of the ping pongs
#   [0] is knocked upside down, which causes the other teens to give each other high fives. (score=-1.00)
#   [1] tries to rise but dikes instead. (score=-0.97)
#   [2] rush walks up in front of the boys, removes a small piece of paper from the bottom of the table, puts a hand on the machine and wrestles with buttons, turns the machine off and pushes a button inside to turn the game back on. (score=-0.99)
#   [3] lands in the cup and one of the boys begins to drink the beer. (score=-0.99) ✅
# → Predicted: 1 | Ground Truth: 3 ❌
#
# Q44: One of the ping pongs lands in the cup and one of the boys begins to drink the beer. the group
#   [0] of teens is sailing down the river with others sailing in the background. (score=-0.99)
#   [1] gets up together and poses with their vests to celebrate. (score=-1.01)
#   [2] continue to play beer pong when one final player is able to throw and land a ping pong ball while standing with his back to the cups at which point the boys celebrate, and laugh. (score=-0.96) ✅
#   [3] does a trick and the liquid is poured on a second table. (score=-0.99)
# → Predicted: 2 | Ground Truth: 2 ✅
#
# Q45: There's a nbc news reporter wearing a red sweater and white shirt talking about dog grooming by scissor wizard a grooming company. the representative from the company
#   [0] is talking about the services they offer and how those dogs participate in dog shows. (score=-1.02) ✅
#   [1] speaks to a woman sitting on a colorful conference room chair next to a brown dog kennel in front of them. (score=-1.00)
#   [2] tells viewers about a dog grooming company, itv with a website. (score=-0.98)
#   [3] in grey sweater and black pants talks about the procedures on grooming dogs in life and techniques. (score=-1.01)
# → Predicted: 2 | Ground Truth: 0 ❌
#
# Q46: The representative from the company is talking about the services they offer and how those dogs participate in dog shows. a groomer
#   [0] is seen using shears to creatively trim the dog's hair and even dye it in colorful shades of red, green, yellow and blue. (score=-1.02) ✅
#   [1] is presenting cookies to the room with a loaf of bread. (score=-1.00)
#   [2] shows crowd opinion for use as their garden service representative. (score=-1.06)
#   [3] speaks to an older man about snow cleaning dogs and showing how it is flectious. (score=-1.00)
# → Predicted: 1 | Ground Truth: 0 ❌
#
# Q47: A woman tries to eat ice cream to a child, but the child refuses to eat the ice cream, then the woman eats the ice cream in the spoon. after
#   [0] , the woman gives ice cream to the child, and then the woman cleans the child's mouth. (score=-0.96) ✅
#   [1] , the child takes out the fork the other child takes out the spoon and eats the ice cream. (score=-1.00)
#   [2] , the child and the woman tries to eat food without ice cream, then they sit and talk with adults in the room. (score=-1.02)
#   [3] , two people wearing red shirts pass through the store's door and inside the market and besides a man and a chimpanzee wearing silver uniforms are watching the woman and child. (score=-1.02)
# → Predicted: 0 | Ground Truth: 0 ✅
#
# Q48: After, the woman gives ice cream to the child, and then the woman cleans the child's mouth. an old woman
#   [0] feeds a boy ice cream. (score=-0.99) ✅
#   [1] hold the child and eats the ice cream, after the woman is giving baby ice cream to the child. (score=-1.01)
#   [2] tries to stop the mother pray while giving a baby something else. (score=-0.99)
#   [3] is standing using a white blower to blow snow. (score=-1.01)
# → Predicted: 2 | Ground Truth: 0 ❌
#
# Q49: Men are lifting heavy weights over their head several times. A man in a blue shirt is watching one of the men. a man in a gray shirt
#   [0] is watching the men on the ground. (score=-0.99)
#   [1] hits a big weight in slow motion. (score=-1.00)
#   [2] is talking to one of the men in the middle of the gym. (score=-1.02)
#   [3] is mimicking the person lifting the weight. (score=-1.02) ✅
# → Predicted: 0 | Ground Truth: 3 ❌
#
# Q50: In home pet groomers demonstrate how to groom a pet. the person
#   [0] puts a setting engage on the pets tongue and leash. (score=-1.01)
#   [1] starts at their butt rise, combing out the hair with a brush from a red. (score=-1.00)
#   [2] is demonstrating how the dog's hair is trimmed with electric shears at their grooming salon. (score=-0.97) ✅
#   [3] installs and interacts with a sleeping pet before moving away. (score=-1.00)
# → Predicted: 2 | Ground Truth: 2 ✅
#
# Q51: A person polish a shoe with a wrapped finger. then
#   [0] , the person remove the wrapping paper to expose a shoe. (score=-1.03)
#   [1] , the person removes the heel heel from the shoe and polish. (score=-1.01)
#   [2] , the person grabs polish paste and water to polish the shoe. (score=-0.96) ✅
#   [3] , a person polish the fingers, then the person puts a black polish. (score=-0.93)
# → Predicted: 3 | Ground Truth: 2 ❌
#
# Q52: Eight people are standing at the studio, one woman walked at the back of the group. the group
#   [0] then begins marching down a fitness track, demonstrating steps, going forward and backward, in between takes several breaks to lift their feet. (score=-1.00)
#   [1] is gathered around a long table into a dance routine. (score=-1.02)
#   [2] started dancing, swirling, shaking their hips, rotating, their arms and hands are moving from side to side, in front. (score=-1.03) ✅
#   [3] continue to discuss the topic of volleyball. (score=-1.01)
# → Predicted: 0 | Ground Truth: 2 ❌
#
# Q53: A man is seen talking to the camera and presents his knife and sharpener. He then glides the knife down the sharpener and shows how other knives work with different sharpeners. he
#   [0] then repeats his advice and using more wax. (score=-0.98)
#   [1] shows the using the sharpener on a piece of wood. (score=-1.00)
#   [2] presents the knife one last time while still speaking to the camera. (score=-0.98) ✅
#   [3] uses scissors to cut the blade as well as metal and talk to the camera at the end. (score=-1.03)
# → Predicted: 0 | Ground Truth: 2 ❌
#
# Q54: A man walks onto the stage to join a band. a man
#   [0] plays harp and flute while two other people play instruments next to him. (score=-1.01)
#   [1] and woman dance around together on the stage. (score=-0.97)
#   [2] dance on the ropes attached to the stage. (score=-1.00)
#   [3] plays up front of a band with a harmonica. (score=-1.01) ✅
# → Predicted: 1 | Ground Truth: 3 ❌
#
# Q55: A man walks onto the stage to join a band. A man plays up front of a band with a harmonica. the keyboardist
#   [0] plays the hip hop and dance moves with the band. (score=-0.97)
#   [1] plays a spirited solo during the song. (score=-1.01) ✅
#   [2] plays his guitar while moving his body around in front of the band. (score=-1.00)
#   [3] sings with the band, twirling his violin as he walks. (score=-1.02)
# → Predicted: 0 | Ground Truth: 1 ❌
#
# Q56: A camera pans away from a road and shows a person's feet moving around. several shots
#   [0] are shown of people riding up a mountain on skis while being pulled down by a rope. (score=-0.99)
#   [1] are shown of people tying their shoes, hitting a button, and checking a watch. (score=-1.03) ✅
#   [2] are shown of people wake boarding. (score=-1.01)
#   [3] are then shown of people riding on snowboards over mountains. (score=-1.01)
# → Predicted: 0 | Ground Truth: 1 ❌
#
# Q57: A camera pans away from a road and shows a person's feet moving around. Several shots are shown of people tying their shoes, hitting a button, and checking a watch. people
#   [0] march around a room wearing funny hats, hats, and shoes. (score=-0.98)
#   [1] then are shown washing a car. (score=-1.02)
#   [2] are then seen running down the road one at a time followed by many more following. (score=-1.02) ✅
#   [3] walk along a road, using bicycles and bagpipes. (score=-1.01)
# → Predicted: 0 | Ground Truth: 2 ❌
#
# Q58: A gymnast put power chalk power on his hands and stands near the pommel horse. then
#   [0] , the gymnast put strength and power item on his body and falls. (score=-0.98)
#   [1] , the gymnast approach the pommel horse to spin around many times. (score=-0.98) ✅
#   [2] , the gymnast blade the board and stands in position facing the pommel horse doing blade moves. (score=-1.00)
#   [3] , the gymnast moves around and flips the chalk power to full weight and continues gymnastics for the next competition, after he turns and stands near the pommel horse. (score=-1.01)
# → Predicted: 1 | Ground Truth: 1 ✅
#
# Q59: A gymnast put power chalk power on his hands and stands near the pommel horse. Then, the gymnast approach the pommel horse to spin around many times. then
#   [0] , the gymnast stand on his hand and jumps to land on the floor, while people applaud. (score=-0.98) ✅
#   [1] , the gymnast put the star light on his hands and jumps high using strength. (score=-1.02)
#   [2] , the gymnast puts fluid on the pommel horse and sit on it to rise the body while position it. (score=-0.99)
#   [3] , the gymnast cross the pommel horse with the long rope while performing handsprings. (score=-0.96)
# → Predicted: 3 | Ground Truth: 0 ❌
#
# Q60: A logo shows that this video is presented by expert village. a man in a small blue boat
#   [0] is pushing a kress of water in a lake while instructing his boarder. (score=-0.98)
#   [1] discusses the topic of hand surfing in a hole and gives hints on how to perform this activity. (score=-1.01) ✅
#   [2] , in the middle of a lake, is skiing. (score=-0.97)
#   [3] is in the water pushing a boat with a sail. (score=-1.02)
# → Predicted: 2 | Ground Truth: 1 ❌
#
# Q61: A man in a small blue boat discusses the topic of hand surfing in a hole and gives hints on how to perform this activity. the man
#   [0] demonstrates how to properly back up a hand surf by requiring an anchor. (score=-0.98)
#   [1] demonstrates tricks that can be done while performing this activity. (score=-1.00) ✅
#   [2] in the small blue boat holds a fish in his hands and then holds the fish while talking about the technique needed to perform this activity. (score=-0.98)
#   [3] is omic on the water as he's riding the speedo on the aerobic machine still pointing down at the water. (score=-1.00)
# → Predicted: 2 | Ground Truth: 1 ❌
#
# Q62: The camera pans to show a man playing a harmonica while sitting on a log beside a river. A woman walks near the train tracks while a train drives by. the woman
#   [0] continues just playing with the tunes she made. (score=-1.02)
#   [1] sees the harmonica playing man in the distance. (score=-1.02) ✅
#   [2] taps a horn intermittently as the camera pans right. (score=-1.00)
#   [3] plays a song on her harmonica while walking away from the train. (score=-0.99)
# → Predicted: 3 | Ground Truth: 1 ❌
#
# Q63: A woman walks near the train tracks while a train drives by. The woman sees the harmonica playing man in the distance. she
#   [0] comes back to the train and continues walking on the subway. (score=-0.98)
#   [1] walks around the rail of the tracks and watches the scenery and the crowds of people. (score=-1.00)
#   [2] watches him and listens to him playing. (score=-1.04) ✅
#   [3] begins playing with the harmonica and stops. (score=-1.03)
# → Predicted: 0 | Ground Truth: 2 ❌
#
# Q64: The woman sees the harmonica playing man in the distance. She watches him and listens to him playing. She walks away leaving the man. the man
#   [0] takes out a wall show from his guitar. (score=-1.01)
#   [1] finishes playing and remains seated. (score=-0.98) ✅
#   [2] jumps over a barrier and lands on the sandy beach. (score=-1.01)
#   [3] plays in a house while the woman looks on. (score=-1.02)
# → Predicted: 1 | Ground Truth: 1 ✅
#
# Q65: A person is shown looking around a city and begins washing windows with his tools. he
#   [0] then brushes right through the window and cleans it off. (score=-1.04)
#   [1] uses a large block cutter to remove smaller blocks until he has the whole of the window covered. (score=-0.99)
#   [2] puts water on a hose and begins cleaning the windows. (score=-1.01)
#   [3] goes up and down the windows at a rapid pace and continues filming himself through the glass. (score=-1.03) ✅
# → Predicted: 1 | Ground Truth: 3 ❌
#
# Q66: A person is shown looking around a city and begins washing windows with his tools. He goes up and down the windows at a rapid pace and continues filming himself through the glass. he
#   [0] continues to work by scrubbing the windows and then by pouring water out. (score=-0.97)
#   [1] takes his clothes off and hangs them up before throwing his plaid shirt into the laundry. (score=-0.99)
#   [2] finishes the glass in record time and turns off the camera. (score=-0.99) ✅
#   [3] spins around to show the different angles of the board and shows pictures of the house in the end. (score=-0.98)
# → Predicted: 0 | Ground Truth: 2 ❌
#
# Q67: A man dressed in yellow and black winter clothes ice fishes on a a frozen lake. the man
#   [0] is reeling in a fish for a long time. (score=-0.96) ✅
#   [1] spins with his fishing pole in the air. (score=-0.97)
#   [2] does a trick on his dirty ice fishing line. (score=-1.02)
#   [3] does numerous tricks as he goes through these beauty course courses of ice covered lakes. (score=-0.99)
# → Predicted: 0 | Ground Truth: 0 ✅
#
# Q68: A man dressed in yellow and black winter clothes ice fishes on a a frozen lake. The man is reeling in a fish for a long time. the mans catch
#   [0] more fish and throws them to the side. (score=-1.02)
#   [1] finally reaches the surface. (score=-0.97) ✅
#   [2] a fish for dinner by making a wish with his mouth. (score=-1.00)
#   [3] one and puts it on a fishing pole in the lake. (score=-0.97)
# → Predicted: 1 | Ground Truth: 1 ✅
#
# Q69: Two children are seen sitting in a tub rubbing their faces and another person's hands interacting. the boy
#   [0] continues to rub water all over his face as well as play with toys and smile at the cameraman. (score=-1.00) ✅
#   [1] walks out of the bathroom laughing to the camera and the girl stands up to rinse her face off. (score=-1.01)
#   [2] then begins washing the other child and ends by copulating with him. (score=-1.01)
#   [3] is now seen pointing down by himself and leads into him holding a comb and blow dryer and speaking to others. (score=-0.96)
# → Predicted: 3 | Ground Truth: 0 ❌
#
# Q70: A woman hands a young boy a stick with a little girl grabbing for her attention. the pinata
#   [0] is lifted and the boy begins swinging at the object. (score=-1.01) ✅
#   [1] pops, and a child in white attempts to hit the pinata, but fails. (score=-0.97)
#   [2] pops out of the playground. (score=-1.03)
#   [3] is hit one after the other, and the girl lets go her hold. (score=-0.99)
# → Predicted: 1 | Ground Truth: 0 ❌
#
# Q71: A woman hands a young boy a stick with a little girl grabbing for her attention. The pinata is lifted and the boy begins swinging at the object. the camera
#   [0] zooms in on the pinata and then the girl. (score=-1.01)
#   [1] is upside down so everyone else can't see the object. (score=-1.01)
#   [2] pans around people watching while he hits the pinata and a little boy is seen clapping behind him. (score=-1.02) ✅
#   [3] zooms in on the boy's head and he looks at the pinata person in the background. (score=-0.99)
# → Predicted: 3 | Ground Truth: 2 ❌
#
# Q72: A woman is playing a violin on the street while various people walk around here and behind her. she
#   [0] continues to play violin while people pass by her. (score=-1.00)
#   [1] continues playing the violin and beginning to intermittently move the sticks up and down. (score=-1.01)
#   [2] smiles into the camera while playing and continues playing the song while several people bend down to tip her and walk around her. (score=-0.99) ✅
#   [3] finishes and walks off, leaving the violin lying on the ground. (score=-1.00)
# → Predicted: 2 | Ground Truth: 2 ✅
#
# Q73: Various pictures of food are shown followed by a person cutting up vegetables and mixing various ingredients into a pot. he
#   [0] shows how the vegetables are chopped for seasoning and then sprinkled into broth and shown with the water boiling. (score=-1.03)
#   [1] cooks up a meal and each are shown eating inside the pot. (score=-0.98)
#   [2] boils food into a bowl and then adds some part of a salad into the bowl. (score=-1.03)
#   [3] then cuts up a piece of bread, scoops out the insides, and fries up some meat. (score=-1.01) ✅
# → Predicted: 1 | Ground Truth: 3 ❌
#
# Q74: Ingredients are sitting on a wooden block. a person
#   [0] adds flour to a baking pan. (score=-1.00)
#   [1] starts mixing the ingredients together. (score=-1.03) ✅
#   [2] puts salt, lemon juice in a pot, then adds eggs, cheese, ham, and some other hoagies. (score=-1.02)
#   [3] is mixing the ingredients in an iron. (score=-1.03)
# → Predicted: 0 | Ground Truth: 1 ❌
#
# Q75: A man is seen walking closer to a pinata while a large group of people stand around him. the man
#   [0] shows off various tapers while swinging at the pinata and throwing them out to the crowd. (score=-0.99)
#   [1] then throws the pin while others watch on the sides. (score=-1.02)
#   [2] spins around several times and throws the stick. (score=-0.99)
#   [3] misses the pinata and hits a person behind him, shown again in slow motion. (score=-0.99) ✅
# → Predicted: 2 | Ground Truth: 3 ❌
#
# Q76: A pair of female hands uses an iron on a piece of baby clothing. the woman
#   [0] wets the garment and scrubs it with a cloth. (score=-0.97)
#   [1] peels the old clothing off the piece and replaces it with dry material. (score=-1.02)
#   [2] sets the iron aside and flips the clothing. (score=-1.01) ✅
#   [3] wraps the garment on top of the blouse, then irons it. (score=-1.01)
# → Predicted: 0 | Ground Truth: 2 ❌
#
# Q77: A pair of female hands uses an iron on a piece of baby clothing. The woman sets the iron aside and flips the clothing. the woman
#   [0] then undresses and irons the shirt. (score=-0.98)
#   [1] places a pair of pants into a bucket. (score=-0.99)
#   [2] shows how to iron a sock correctly. (score=-1.00)
#   [3] uses the iron on the other side of the clothing. (score=-1.01) ✅
# → Predicted: 0 | Ground Truth: 3 ❌
#
# Q78: The woman sets the iron aside and flips the clothing. The woman uses the iron on the other side of the clothing. the woman
#   [0] scrubs the clothing with her hands. (score=-1.01)
#   [1] quickly picks up and irons, flames dancing over the clothing. (score=-1.02)
#   [2] sets the iron aside. (score=-0.98) ✅
#   [3] crosses her arms in front of her and it's gone. (score=-1.00)
# → Predicted: 2 | Ground Truth: 2 ✅
#
# Q79: We see a chair with a pillow on it. a man holding a cat
#   [0] does curling. (score=-0.97)
#   [1] starts hitting objects on an item. (score=-1.01)
#   [2] sits down on the chair. (score=-1.00) ✅
#   [3] is wrapping a box. (score=-1.04)
# → Predicted: 0 | Ground Truth: 2 ❌
#
# Q80: We see a chair with a pillow on it. A man holding a cat sits down on the chair. The man clips the cats fingernails. the man
#   [0] strokes the cat's head. (score=-1.03) ✅
#   [1] then clips the cat nails. (score=-1.01)
#   [2] puts the cat down and boxes it with paper. (score=-0.98)
#   [3] gives the cats ears. (score=-1.00)
# → Predicted: 2 | Ground Truth: 0 ❌
#
# Q81: A man holding a cat sits down on the chair. The man clips the cats fingernails. The man strokes the cat's head. the man
#   [0] sits back down on the chair. (score=-1.04)
#   [1] takes the cat to the other room. (score=-1.00)
#   [2] stands up and walks down the sidewalk. (score=-0.98)
#   [3] plays with the cat rocking it back and forth. (score=-1.02) ✅
# → Predicted: 2 | Ground Truth: 3 ❌
#
# Q82: A young girl in a green leotard begins twirling a baton and doing tricks. the girl
#   [0] does this in the beginning while using her foot and one hand to move around her body. (score=-0.98)
#   [1] begins to do some of her routine and does a few hip spins. (score=-1.00)
#   [2] puts their hands together, and twirl together like a ballet dancer. (score=-0.99)
#   [3] begins to incorporate her arms and does a flip and continues to flip the baton over her hands and arms. (score=-0.99) ✅
# → Predicted: 0 | Ground Truth: 3 ❌
#
# Q83: The girl begins to incorporate her arms and does a flip and continues to flip the baton over her hands and arms. as the young lady
#   [0] continues her performance, she twirls the baton between her legs and over her head, catches it and does a gallop. (score=-1.00) ✅
#   [1] is still serving the baton, she places the extension on her left hand and does a full 180 degree spin in one flip. (score=-1.01)
#   [2] becomes more involved in the ballet, she does a final dismount to bring her elbows down and her upper body straight. (score=-1.00)
#   [3] is zapping her arms and is practicing her baton twirling technique, she grabs the baton from the ground and shows herself victorious while her coach claps. (score=-0.97)
# → Predicted: 3 | Ground Truth: 0 ❌
#
# Q84: As the young lady continues her performance, she twirls the baton between her legs and over her head, catches it and does a gallop. the rest of the young girl's performance
#   [0] is replayed in slow motion. (score=-1.00)
#   [1] is a set of twirls and twist and then she runs off the floor to finish her performance. (score=-1.05) ✅
#   [2] is shown several times and ends by showcasing her back to the both the camera and a final focus of her performance. (score=-1.00)
#   [3] is replayed, ending with the young lady clapping her hands joyfully. (score=-0.99)
# → Predicted: 3 | Ground Truth: 1 ❌
#
# Q85: We see a man in a driveway cleaning snow from his car. the man
#   [0] cleans the snow under his windshield wipers. (score=-0.92) ✅
#   [1] wet his car and wipes it down. (score=-1.02)
#   [2] moves the snow out of the front bumper of his car and pours gasoline on it. (score=-0.98)
#   [3] removes the pieces of the line off his windshield. (score=-1.00)
# → Predicted: 0 | Ground Truth: 0 ✅
#
# Q86: We see a man in a driveway cleaning snow from his car. The man cleans the snow under his windshield wipers. we
#   [0] see the old man's garage and what looks like a boat in the water. (score=-1.00)
#   [1] see the building behind the car. (score=-1.04) ✅
#   [2] zoom in on the cabin. (score=-0.99)
#   [3] see the mans silver car gliding by in the background. (score=-1.04)
# → Predicted: 2 | Ground Truth: 1 ❌
#
# Q87: The man cleans the snow under his windshield wipers. We see the building behind the car. We do a 360 spin to see the parking lot. the man
#   [0] finishes and turns off the wipers. (score=-1.04)
#   [1] opens the doors on his car and gets in. (score=-0.99) ✅
#   [2] finishes and slides out of the car. (score=-1.00)
#   [3] puts up the camera. (score=-0.96)
# → Predicted: 3 | Ground Truth: 1 ❌
#
# Q88: A man in a blue shirt and shorts lifts a large weight over his head. Another man is filming it. The same man comes back and lifts the weight over his head again. he
#   [0] drops it on the ground and walks away. (score=-0.99) ✅
#   [1] again lifts the weight over his head. (score=-0.99)
#   [2] drops it and runs towards the camera. (score=-0.99)
#   [3] drops it onto the floor where it gets stuck. (score=-1.00)
# → Predicted: 0 | Ground Truth: 0 ✅
#
# Q89: A man is seen throwing a dart onto a board and leads into a woman speaking. the man
#   [0] tosses darts into the water while people measure the distance and run after them. (score=-1.00)
#   [1] gives her several tips and she continues creating darts. (score=-0.98)
#   [2] throws several more darts while taking the time to speak to the woman. (score=-0.99) ✅
#   [3] holds behind him and the woman continues speaking. (score=-0.97)
# → Predicted: 3 | Ground Truth: 2 ❌
#
# Q90: A group of people are standing in the middle of a forest with a trail of pebbles separating them from a beautiful crystal clear body of water. the camera
#   [0] then goes right side up and shows a lot of scenery on the left side. (score=-0.97)
#   [1] follows the couple kayaking behind the group on the trail moving back and fourth on the murky water in the forest. (score=-1.02)
#   [2] moves across the water and several people on boats and jet-skis are moving in the water near a large wave. (score=-0.99) ✅
#   [3] zooms in on the foamy waters as well as the nearby cliffs and forest surrounding it. (score=-1.00)
# → Predicted: 0 | Ground Truth: 2 ❌
#
# Q91: The camera moves across the water and several people on boats and jet-skis are moving in the water near a large wave. More large waves begin to surface and a man begins surfing the waves. the forest
#   [0] is then shown clearly under a large wide wave. (score=-1.02)
#   [1] is then shown and surf boards appear that are washed up against the banks of the water. (score=-0.97) ✅
#   [2] starts to get darker and darker as the large wave picks up and men continue to sail around it. (score=-1.02)
#   [3] of trees quickly moves over the trailing wave and they follow suit as well. (score=-0.99)
# → Predicted: 1 | Ground Truth: 1 ✅
#
# Q92: A large patch of grass is shown. a man
#   [0] belly flops on some grass before a newscaster announces the story. (score=-1.00)
#   [1] stretches in front of it. (score=-0.99)
#   [2] is shown inside while a machine is working. (score=-1.03)
#   [3] is mowing the yard next to the bushes. (score=-1.01) ✅
# → Predicted: 1 | Ground Truth: 3 ❌
#
# Q93: A pilates instructor on skates explains how to strap your risk protectors tight and shows that you need knee pads to protect your knees. the lady
#   [0] starts with two small straps and it puts her into a squatting position with feet fully placed over her knee and her hands suspended and ready. (score=-1.02)
#   [1] then explains the skates movement and how to use the breaks that is in the back of the skates. (score=-1.02) ✅
#   [2] then puts lotion in both of her hands and rubs them along your knees while the instructor washes them. (score=-1.01)
#   [3] shows how to harness and strap your weight on properly and she moves away from the mounting as she reaches for her left knee. (score=-0.99)
# → Predicted: 3 | Ground Truth: 1 ❌
#
# Q94: A woman wearing a tan apron is holding a knife and talking. She then shows an appliance on the table and tilts it upwards. she
#   [0] turns a dial on the appliance and sets it back down. (score=-0.97) ✅
#   [1] continues sliding the blade over the appliance. (score=-1.01)
#   [2] takes a quarter of an inch of the device and holds it against a piece of cake. (score=-1.00)
#   [3] removes a lemon from a jar and places it into a pot. (score=-0.98)
# → Predicted: 0 | Ground Truth: 0 ✅
#
# Q95: She then shows an appliance on the table and tilts it upwards. She turns a dial on the appliance and sets it back down. she
#   [0] shows several shots of the chair in the end. (score=-1.01)
#   [1] picks the knife back up and places it on the appliance. (score=-0.98) ✅
#   [2] pokes the vacuum nozzle in the top seam of the vacuum cleaner and adds fuel to it while still keeping the vacuum nozzle up. (score=-0.98)
#   [3] also shows how to use tubing no a string is attached to it and she explaining the use of the tubing. (score=-1.02)
# → Predicted: 1 | Ground Truth: 1 ✅
#
# Q96: She turns a dial on the appliance and sets it back down. She picks the knife back up and places it on the appliance. she
#   [0] gets up and starts brushing the blade. (score=-1.04)
#   [1] uses a tool to pinch the wax off of the knife. (score=-0.99)
#   [2] turns the dial again on the appliance. (score=-1.00) ✅
#   [3] jumps up and throws something into a container shaped like a snowboard. (score=-0.99)
# → Predicted: 1 | Ground Truth: 2 ❌
#
# Q97: She picks the knife back up and places it in the appliance and slowly draws it back several times. she
#   [0] slices a tomato on a wood block with the knife. (score=-1.01) ✅
#   [1] removes the rubber band off of the knife and gets it across the blade. (score=-1.00)
#   [2] continues using the appliance to put the fancy knife on the box. (score=-1.02)
#   [3] stands up from the chair and walks towards the stairs before finally leaving the room. (score=-0.99)
# → Predicted: 3 | Ground Truth: 0 ❌
#
# Q98: She picks the knife back up and places it in the appliance and slowly draws it back several times. She slices a tomato on a wood block with the knife. she
#   [0] decorates the knife with green and red maracas. (score=-1.02)
#   [1] positions the knife front and back and finishes by pushing it straight across the square board. (score=-1.00)
#   [2] then demonstrates how to sharpen the knife and finishes by putting a metal rod in front of the plate of spaghetti that she just sharpened. (score=-1.02)
#   [3] grabs a second knife and puts it in the appliance. (score=-1.02) ✅
# → Predicted: 1 | Ground Truth: 3 ❌
#
# Q99: A man wearing a black clothes is sharpening the knife on a stone. The man beside him on blue long sleeves drawing something on the table with his finger. the man
#   [0] continues sharpening the knife and standing on the middle of the stone. (score=-1.01)
#   [1] turn the knife to sharpen the other side and then wipe it with paper towel. (score=-1.01) ✅
#   [2] stops sharpening the knife and draws on the stone again. (score=-0.95)
#   [3] down retracts from the knife and starts sharpening the knife back up again. (score=-1.04)
# → Predicted: 2 | Ground Truth: 1 ❌
#
# Q100: A man is seen speaking to the camera while a shot of a person playing basketball shows behind. the man
#   [0] continues going around the basket while the camera is sitting in the back. (score=-0.99)
#   [1] continues to speak and leads into more clips of him playing tennis. (score=-1.00)
#   [2] pulls the ball up on the court while still speaking to the camera. (score=-0.95)
#   [3] continues speaking as more shots are shown of the boy playing basketball. (score=-1.02) ✅
# → Predicted: 2 | Ground Truth: 3 ❌
#
# Final Accuracy on 100 samples: 28/100 = 28.00%

# %% [markdown]
# <h1 align="center" style="font-family: 'Braniella', cursive; font-style: italic; font-size: 96px;">
#   Thank You
# </h1>
